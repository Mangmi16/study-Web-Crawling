# %%
from selenium import webdriver


chrome_path = 'C:\\Users\\Administrator\\Desktop\\py.temp\\craling\\chromedriver.exe'
driver = webdriver.Chrome(chrome_path)
url = "https://www.naver.com/"
driver.get(url)
import time
time.sleep(2)


요소_검색창 = driver.find_element_by_id("query")

요소_검색창.click()

요소_검색창.send_keys('됐다')

요소_검색창.send_keys('\n')

뉴스 = driver.find_element_by_xpath('//*[@id="lnb"]/div[1]/div/ul/li[9]/a')
뉴스.click()

for i in range(1,11):
    driver.find_element_by_link_text(str(i)).click()
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7024/3998298939.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7024/3998298939.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   요소_검색창 = driver.find_element_by_id("query")
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7024/3998298939.py:29: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   뉴스 = driver.find_element_by_xpath('//*[@id="lnb"]/div[1]/div/ul/li[9]/a')
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7024/3998298939.py:33: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text(str(i)).click()

# %% [markdown]
# #저장한 리스트를 csv 파일로 저장하기
# #csv
# 1.리스트 형태로 데이터를 모아준다.
# 2.리스트를 합해서 dataframe으로 만들어 준다.
# dataframe을 csv로 (~로 = to)내보낸다.
#
# ##데이터 프레임 만들기
# 데이터프레임_이름 = pd.DataFrame() <- 선언을 해 준다
# 데이터프레임_이름['행이름1'] = 리스트1
# ...
# 데이터프레임_이름['행이름n'] = 리스트n
#
# #DataFrame 을 csv로 (~로 = to ) 내보낸다
# 데이터프레임_이름.to_csv(경로, 인덱스 = True, encoding="utf-8-sig")
# +엑셀로도 저장

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

chrome_path = 'C:\\Users\\Administrator\\Desktop\\py.temp\\craling\\chromedriver.exe'
driver = webdriver.Chrome(chrome_path)
url = "https://www.naver.com/"
driver.get(url)
import time
time.sleep(1)



요소_검색창 = driver.find_element_by_id('query')


요소_검색창.click()

요소_검색창.send_keys('겨울')
요소_검색창.send_keys('\n')
뉴스 = driver.find_element_by_xpath('//*[@id="lnb"]/div[1]/div/ul/li[9]/a')
뉴스.click()



html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

content_list = soup.find('ul','list_news')

li_list = content_list.find_all('li')

#제목 본문 언론사 이름,개시날짜시간,
news_tit = content_list.find_all('a','news_tit')

contents = content_list.find_all('a','api_txt_lines dsc_txt_wrap')

press_name = content_list.find_all('a','info press')

press_time = content_list.find_all('span','info')
press_time_list = []
press_name_list = []
contents_list = []
news_tit_list = []

for i in news_tit:
    news_tit_list.append(i.text.strip())
    news_tit_list 


for i in li_list:
    li_list_list.append(i.text.strip())
    li_list_list



for i in press_name:
    press_name_list.append(i.text.strip())
    press_name_list




for i in press_time:
    press_time_list.append(i.text.strip())
    press_time_list
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7024/1922711938.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7024/1922711938.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   요소_검색창 = driver.find_element_by_id('query')
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7024/1922711938.py:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   뉴스 = driver.find_element_by_xpath('//*[@id="lnb"]/div[1]/div/ul/li[9]/a')

# %%
# press_time_list = []
# press_name_list = []
# li_list_list = []
# news_tit_list = []

import pandas as pd

겨울기사_data = pd.DataFrame()


겨울기사_data['제목'] = news_tit_list
겨울기사_data['내용'] = li_list_list
겨울기사_data['언론사'] = press_name_list


f_name = "C:\\Users\\Administrator\\Desktop\\py.temp\\craling\\test.csv"
겨울기사_data.to_csv(f_name, encoding = 'utf-8-sig')

# %%
from selenium import webdriver

import math
chrome_path = 'C:\\Users\\Administrator\\Desktop\\py.temp\\craling\\chromedriver.exe'
driver = webdriver.Chrome(chrome_path)
url = "https://www.naver.com/"
driver.get(url)
import time
time.sleep(2)


요소_검색창 = driver.find_element_by_id("query")

요소_검색창.click()

요소_검색창.send_keys('겨울')

요소_검색창.send_keys('\n')

뉴스 = driver.find_element_by_xpath('//*[@id="lnb"]/div[1]/div/ul/li[9]/a')
뉴스.click()

cnt = input('건수를 입력')
page_cnt = math.ceil(int(cnt)/10)



for i in range(1,page_cnt+1):
    driver.find_element_by_link_text(str(i)).click()
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/915214651.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/915214651.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   요소_검색창 = driver.find_element_by_id("query")
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/915214651.py:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   뉴스 = driver.find_element_by_xpath('//*[@id="lnb"]/div[1]/div/ul/li[9]/a')
# 건수를 입력66
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/915214651.py:27: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text(str(i)).click()

# %%
from selenium import webdriver

import math
chrome_path = 'C:\\Users\\Administrator\\Desktop\\py.temp\\craling\\chromedriver.exe'
driver = webdriver.Chrome(chrome_path)
url = "https://www.naver.com/"
driver.get(url)
import time
time.sleep(2)


요소_검색창 = driver.find_element_by_id("query")

요소_검색창.click()

요소_검색창.send_keys('겨울')

요소_검색창.send_keys('\n')

뉴스 = driver.find_element_by_xpath('//*[@id="lnb"]/div[1]/div/ul/li[9]/a')
뉴스.click()



index = []
title_list = []
contents_list = []
date_list  = []
press_list = []
no = 1


for i in li_list:
    try : 
       title = i.find('a', 'news_tit').get_text().strip()
    
    except:
        continue
    else:
        # 각 변수명으로 추출
        contents = i.find('a', 'api_txt_lines dsc_txt_wrap').get_text().strip()
        date = i.find('span', 'info').get_text().strip()
        press = i.find('a', class_="info press").get_text().strip()
        print('1. 제목: ', title)
        print('2. 내용: ', contents)
        print('3. 시간: ', date)
        print('4. 언론사: ', press)
        
        # 리스트에 저장
        title_list.append(title)
        contents_list.append(contents)
        date_list.append(date)
        press_list.append(press)

print("\n")
print("="*100)
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/2310573170.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/2310573170.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   요소_검색창 = driver.find_element_by_id("query")
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/2310573170.py:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   뉴스 = driver.find_element_by_xpath('//*[@id="lnb"]/div[1]/div/ul/li[9]/a')
# 1. 제목:  바이든, 베이징 겨울 올림픽 ‘외교적 보이콧’ 고려
# 2. 내용:  조 바이든 미국 대통령이 2022년 베이징 겨울 올림픽을 미국이 외교적으로 검토하는 것을 고려하고 있다고... 앞서, <워싱턴포스트>의 조시 로긴 칼럼니스트는 바이든 대통령이 베이징 겨울 올림픽에 대한 외교적 보이콧...
# 3. 시간:  5시간 전
# 4. 언론사:  한겨레언론사 선정
# 1. 제목:  "포근한 겨울" 휠라, 김유정과 '윈터 다운' 화보
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup     
from selenium import webdriver
import time
import sys
import math
chrome_path = 'C:\\Users\\Administrator\\Desktop\\py.temp\\craling\\chromedriver.exe'
driver = webdriver.Chrome(chrome_path)
url = "https://korean.visitkorea.or.kr/main/main.do#home"
driver.get(url)
import time
time.sleep(2)


요소_검색창1 = driver.find_element_by_xpath('//*[@id="openSearchFormInput"]')

요소_검색창1.click()
요소_검색창2 = driver.find_element_by_xpath('//*[@id="searchInput"]')
요소_검색창2.send_keys('부산')

요소_검색창2.send_keys('\n')


full_html = driver.page_source
soup = BeautifulSoup(full_html, 'html.parser')
content_list = soup.find('ul','list_thumType type1')


index1 = []
title_list1 = []
contents_list1 = []
press_list1 = []
no = 1
li_list = content_list.find_all('li')
for i in li_list:
    try : 
       title = i.find('div', 'tit').get_text().strip()
    
    except:
        continue
    else:
        contents = i.find('div', 'area_txt').get_text().strip()
        site = i.find('span',"#").get_text().strip()
        print('1. 제목: ', tit0le)
        print('2. 내용: ', conte0nts)
        print('3. 장소: ', site)
        

title_list1.append(title)
contents_list1.append(contents)
press_list1.append(site)

print("\n")
print("="*100)0
# Out:
#   File "C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/527847296.py", line 54
#     print("="*100)0
#                   ^
# SyntaxError: invalid syntax

# %%
from selenium import webdriver
from bs4 import BeautifulSoup     
from selenium import webdriver
import time
import sys
import math
chrome_path = 'C:\\Users\\Administrator\\Desktop\\py.temp\\craling\\chromedriver.exe'
driver = webdriver.Chrome(chrome_path)
url = "https://korean.visitkorea.or.kr/main/main.do#home"
driver.get(url)
import time
time.sleep(2)


요소_검색창1 = driver.find_element_by_xpath('//*[@id="openSearchFormInput"]')

요소_검색창1.click()
요소_검색창2 = driver.find_element_by_xpath('//*[@id="searchInput"]')
요소_검색창2.send_keys('부산')

요소_검색창2.send_keys('\n')
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/1540709150.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/1540709150.py:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   요소_검색창1 = driver.find_element_by_xpath('//*[@id="openSearchFormInput"]')
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/1540709150.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   요소_검색창2 = driver.find_element_by_xpath('//*[@id="searchInput"]')

# %%
# 해당 페이지의 요약본을 긁어오는 
def news_summary(title_list=title_list,contents_list=contents_list,
                 date_list=date_list,press_list=press_list):
    
    # 요약본 : 제목/내용/신문사/개시시간을 긁어왔다.
    for j in li_list:
        try : 
           title = j.find('a', 'news_tit').get_text().strip()

        except:
            continue
        else:
            # 각 변수명으로 추출
            contents = j.find('a', 'api_txt_lines dsc_txt_wrap').get_text().strip()
            date = j.find('span', 'info').get_text().strip()
            press = j.find('a', class_="info press").get_text().strip()

            # 원하는 모양으로 출력
            print('1. 제목: ', title)
            print('2. 내용: ', contents)
            print('3. 시간: ', date)
            print('4. 언론사: ', press)

            # 리스트에 저장
            title_list.append(title)
            contents_list.append(contents)
            date_list.append(date)
            press_list.append(press)

        print("\n")
        print("="*100)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup     
from selenium import webdriver
import time
import sys
import math
chrome_path = 'C:\\Users\\Administrator\\Desktop\\py.temp\\craling\\chromedriver.exe'
driver = webdriver.Chrome(chrome_path)
url = "https://korean.visitkorea.or.kr/main/main.do#home"
driver.get(url)
import time
time.sleep(2)


요소_검색창1 = driver.find_element_by_xpath('//*[@id="openSearchFormInput"]')

요소_검색창1.click()
요소_검색창2 = driver.find_element_by_xpath('//*[@id="searchInput"]')
요소_검색창2.send_keys('부산')

요소_검색창2.send_keys('\n')



for i in range(1,11):
    driver.find_element_by_xpath('''//*[@id="listBody"]/ul/li[%s]/div[2]/div[1]/a''' %i).click()
    driver.back()
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/1131638194.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/1131638194.py:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   요소_검색창1 = driver.find_element_by_xpath('//*[@id="openSearchFormInput"]')
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/1131638194.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   요소_검색창2 = driver.find_element_by_xpath('//*[@id="searchInput"]')
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/1131638194.py:26: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('''//*[@id="listBody"]/ul/li[%s]/div[2]/div[1]/a''' %i).click()
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup     
from selenium import webdriver
import time
import sys
import math
chrome_path = 'C:\\Users\\Administrator\\Desktop\\py.temp\\craling\\chromedriver.exe'
driver = webdriver.Chrome(chrome_path)
url = "https://korean.visitkorea.or.kr/main/main.do#home"
driver.get(url)
import time
time.sleep(2)


요소_검색창1 = driver.find_element_by_xpath('//*[@id="openSearchFormInput"]')

요소_검색창1.click()
요소_검색창2 = driver.find_element_by_xpath('//*[@id="searchInput"]')
요소_검색창2.send_keys('부산')

요소_검색창2.send_keys('\n')

for i in range(1,12):
    try:
        driver.find_element_by_xpath('//*[@id="listBody"]/ul/li[%s]/div[2]/div[1]/a'%i).click()
        time.sleep(2)
        driver.back()
    except:
        continue
        driver.back()
# Out:
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/773687379.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/773687379.py:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   요소_검색창1 = driver.find_element_by_xpath('//*[@id="openSearchFormInput"]')
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/773687379.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   요소_검색창2 = driver.find_element_by_xpath('//*[@id="searchInput"]')
# C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_7500/773687379.py:25: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="listBody"]/ul/li[%s]/div[2]/div[1]/a'%i).click()

# %%
from selenium import webdriver
from bs4 import BeautifulSoup     
from selenium import webdriver
import time
import sys
import math
chrome_path = 'C:\\Users\\Administrator\\Desktop\\py.temp\\craling\\chromedriver.exe'
driver = webdriver.Chrome(chrome_path)
url = "https://korean.visitkorea.or.kr/main/main.do#home"
driver.get(url)
import time
time.sleep(2)


요소_검색창1 = driver.find_element_by_xpath('//*[@id="openSearchFormInput"]')

요소_검색창1.click()
요소_검색창2 = driver.find_element_by_xpath('//*[@id="searchInput"]')
요소_검색창2.send_keys('부산')

요소_검색창2.send_keys('\n')

for i in range(1,12):
    try:
        driver.find_element_by_xpath('//*[@id="listBody"]/ul/li[%s]/div[2]/div[1]/a'%i).click()
        time.sleep(2)
        driver.back()
    except:
        continue
        driver.back()
