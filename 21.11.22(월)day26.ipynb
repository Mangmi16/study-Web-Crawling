# %%
def single_page(no):
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    head = soup.find('div', class_="titleType1")
    body = soup.find('div',class_="blind")


    try:
        title = head.find('h2').text.strip()
    except:
        print("내용이 없습니다")
        return no
    else:
        region_date = head.find('div','area_address').find_all('span')
        region = region_date[0].text.strip()
        date = region_date[1].text.strip()
        likes = head.find('span',id="conLike").text.strip()
        views = head.find('span', id="conRead").text.strip()
        body = soup.find('div',class_="blind")


        print("article no : ", no)
        print("제목 : ", title)
        print("지역 : ", region)
        print("날짜 : ", date)
        print("좋아요 : ", likes)
        print("조회수 : ", views)
        print("해쉬태그 : ", hashtag)
        print("본문 : ", body)
        print("=-"*60)

        title_li_idv.append(title)
        contents_li_idv.append(body)
        date_li_idv.append(date)
        likes_li_idv.append(likes)
        views_li_idv.append(views)
        #지역
        region_li_idv.append(region)
        #해쉬태그
        hashtag_li_idv.append(hashtag)
        
        
        return no

# %%
import warnings
warnings.filterwarnings("ignore")
from selenium import webdriver
from bs4 import BeautifulSoup     
import time
import sys
import math

title_li_idv = []
contents_li_idv = []
date_li_idv = []
likes_li_idv = []
views_li_idv = []
region_li_idv = []
hashtag_li_idv = []

검색건수 = int(input("건수를입력"))
page = math.ceil(검색건수/10)

chrome_path = '/Users/inhyeoksong/Desktop/codding/wc/chromedriver'
driver = webdriver.Chrome(chrome_path)
url = "https://korean.visitkorea.or.kr/main/main.do#home"
driver.maximize_window()
driver.get(url)
import time
time.sleep(2)


요소_검색창1 = driver.find_element_by_xpath('//*[@id="inp_search"]')

요소_검색창1.click()
요소_검색창2 = driver.find_element_by_xpath('//*[@id="searchInput"]')
요소_검색창1.send_keys('부산')

요소_검색창1.send_keys('\n')
time.sleep(2)
no = 1
for i in range(1,page+1):
    if i >= 검색건수:
        print("땡!")
        break
        
    else:        
        time.sleep(2)
        for j in range(1,12):
            try:

                driver.find_element_by_xpath('//*[@id="listBody"]/ul/li[%s]/div[2]/div[1]/a'%j).click()
                print("상세페이지 들어가기 완료")                      
                time.sleep(2)
                
                no=single_page(no)
                print("상세페이지 크롤링 완료")
                no+=1
                time.sleep(2)
                driver.back()
                print('뒤로가기 완료')
                print("넘버 :",no)
            except:
                continue
                driver.back()
    if i%5 == 1:
        driver.find_element_by_link_text('다음').click()
    else:
        
        driver.find_element_by_link_text(str(i)).click()
# Out:
# 건수를입력4
# 상세페이지 들어가기 완료
# article no :  1
# 제목 :  4코스부산의 자연생태 체험 코스
# 지역 :  부산
# 날짜 :  코스 총거리 : 28.68km
# 좋아요 :  13
# 조회수 :  13.4K
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /var/folders/cb/87qggcjj1kv9lvkrzx8s53tc0000gn/T/ipykernel_14795/477750508.py in <module>
#      61                 driver.back()
#      62     if i%5 == 1:
# ---> 63         driver.find_element_by_link_text('다음').click()
#      64     else:
#      65
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_link_text(self, link_text)
#     560             stacklevel=2,
#     561         )
# --> 562         return self.find_element(by=By.LINK_TEXT, value=link_text)
#     563
#     564     def find_elements_by_link_text(self, text) -> WebElement:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#    1236             value = '[name="%s"]' % value
#    1237
# -> 1238         return self.execute(Command.FIND_ELEMENT, {
#    1239             'using': by,
#    1240             'value': value})['value']
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     416         response = self.command_executor.execute(driver_command, params)
#     417         if response:
# --> 418             self.error_handler.check_response(response)
#     419             response['value'] = self._unwrap_value(
#     420                 response.get('value', None))
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#     244
#     245     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"link text","selector":"다음"}
#   (Session info: chrome=96.0.4664.55)
# Stacktrace:
# 0   chromedriver                        0x0000000105f2e519 __gxx_personality_v0 + 577193
# 1   chromedriver                        0x0000000105eba663 __gxx_personality_v0 + 102387
# 2   chromedriver                        0x0000000105a81d28 chromedriver + 171304
# 3   chromedriver                        0x0000000105ab6c9c chromedriver + 388252
# 4   chromedriver                        0x0000000105ae8b04 chromedriver + 592644
# 5   chromedriver                        0x0000000105ad3ddd chromedriver + 507357
# 6   chromedriver                        0x0000000105ae68ab chromedriver + 583851
# 7   chromedriver                        0x0000000105ad40a3 chromedriver + 508067
# 8   chromedriver                        0x0000000105aaa5ae chromedriver + 337326
# 9   chromedriver                        0x0000000105aab8d5 chromedriver + 342229
# 10  chromedriver                        0x0000000105eea75f __gxx_personality_v0 + 299247
# 11  chromedriver                        0x0000000105f0169a __gxx_personality_v0 + 393258
# 12  chromedriver                        0x0000000105f06f5b __gxx_personality_v0 + 415979
# 13  chromedriver                        0x0000000105f02a3a __gxx_personality_v0 + 398282
# 14  chromedriver                        0x0000000105edf37c __gxx_personality_v0 + 253196
# 15  chromedriver                        0x0000000105f1e458 __gxx_personality_v0 + 511464
# 16  chromedriver                        0x0000000105f1e5e1 __gxx_personality_v0 + 511857
# 17  chromedriver                        0x0000000105f35968 __gxx_personality_v0 + 606968
# 18  libsystem_pthread.dylib             0x00007fff2040d8fc _pthread_start + 224
# 19  libsystem_pthread.dylib             0x00007fff20409443 thread_start + 15

# %%
스크롤다운 함수
def scroll_down(driver):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
    time.sleep(1)


#현재 시간 저장하기
now = time.localtime() #현재시간 now로 저장하기
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

f_dir = 'c:\\temp\\' #입력받은 경로

print(f_dir+query_txt+'-'+s)

import os

os.makedirs(f_dir+query_txt+'-'+s) 
os.chdir(f_dir+query_txt+'-'+s)
# 크롤링 결과 저장할 폴더 이름
f_dir_final = f_dir+query_txt+'-'+s


## 자동으로 스크롤 다운 해주는 함수
def scroll_down(driver):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
    
scroll_down(driver)


file_no = 0 # 이미지를 저장할 파일 이름
count = 1
img_src_list = [] # 이미지의 src 태그를 담아둘 리스트

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
 
# 원하는 사진들이 있는 body 지정
img_src = soup.find("div", 'box_txtPhoto')
# 지정한 바디에서 'img' 태그값을 가지는 요소들 모두 데려온다
img_src = img_src.find_all("img")

# 추출한 이미지html 태그를 img_src_list에 담아 준다
for i in img_src :
    # Src 태그에 해당되는 태그값만 img_src_list에 담아 준다
    img_src_list.append(i['src']) 
    count += 1


import urllib
import urllib.request

# 각 링크에서 이미지 다운받아오기. 
for i in range(0,len(img_src_list)) :
    try :
        print(1)
        urllib.request.urlretrieve(img_src_list[i],str(file_no)  + '.jpg')
        print(2)
    except :
        continue        
    file_no += 1                
    time.sleep(0.5)  
    print("%s번째 이미지 저장중.." %file_no)

# %%
class Myspaider
